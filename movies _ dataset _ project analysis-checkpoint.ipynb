# %%
#importing libararies 
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv("movies.csv")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.isnull().sum()
# Out:
# name           0
# rating        77
# genre          0
# year           0
# released       2
# score          3
# votes          3
# director       0
# writer         3
# star           1
# country        3
# budget      2171
# gross        189
# company       17
# runtime        4
# dtype: int64

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df["budget"] = df["budget"].fillna(0)

df["gross"] = df["gross"].fillna(0)

df["votes"] = df["votes"].fillna(0)

df["company"] = df["company"].fillna("unknown")

# %%
df.isnull().sum()
# Out:
# name         0
# rating      77
# genre        0
# year         0
# released     2
# score        3
# votes        0
# director     0
# writer       3
# star         1
# country      3
# budget       0
# gross        0
# company      0
# runtime      4
# dtype: int64

# %%
df["budget"] = df["budget"].astype("int64")

df["gross"] = df["gross"].astype("int64")

df["votes"] = df["votes"].astype("int64")

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.drop_duplicates()
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.describe()
# Out:
#               year        score         votes        budget         gross  \
# count  7668.000000  7665.000000  7.668000e+03  7.668000e+03  7.668000e+03
# mean   2000.405451     6.390411  8.807403e+04  2.551350e+07  7.656567e+07
# std      11.153508     0.968842  1.633011e+05  3.858954e+07  1.641217e+08
# min    1980.000000     1.900000  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1991.000000     5.800000  9.100000e+03  0.000000e+00  3.860582e+06
# 50%    2000.000000     6.500000  3.300000e+04  1.200000e+07  1.895543e+07
# 75%    2010.000000     7.100000  9.300000e+04  3.200000e+07  7.262022e+07
# max    2020.000000     9.300000  2.400000e+06  3.560000e+08  2.847246e+09
#
#            runtime
# count  7664.000000
# mean    107.261613
# std      18.581247
# min      55.000000
# 25%      95.000000
# 50%     104.000000
# 75%     116.000000
# max     366.000000

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score    votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000     Harold Ramis
#
#                     writer            star         country    budget  \
# ...

# %%
# the total gross at each year
df.groupby(["year"])["gross"].sum()
# Out:
# year
# 1980     2483666964
# 1981     2520064889
# 1982     3187580517
# 1983     2750004626
# 1984     3533092196
# 1985     3691509283
# 1986     3647511836
# 1987     4033434255
# 1988     4840385631
# 1989     6087250779
# 1990     6804235860
# 1991     6254770668
# 1992     7334167717
# 1993     8053959337
# 1994     9062925753
# 1995     9448305484
# 1996     9819527991
# 1997    13112275767
# 1998    11176023159
# 1999    13509638121
# 2000    13454129869
# 2001    15617625148
# 2002    17003436520
# 2003    17661932024
# 2004    18721747812
# 2005    17866609897
# 2006    18654070363
# 2007    20383671799
# 2008    21702162009
# 2009    23338680609
# 2010    23106595534
# 2011    24837686836
# 2012    25476190195
# 2013    25995848674
# 2014    26491482563
# 2015    26746011088
# 2016    28938844792
# 2017    28485248415
# 2018    28085289459
# 2019    30339653041
# 2020     2848298792
# Name: gross, dtype: int64

# %%
# the most movie has the maximum gross at each year
df.groupby(["year"])["gross" ,"name"].max()
# Out:
# <ipython-input-42-668bbcad091b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["year"])["gross" ,"name"].max()
#            gross                                name
# year
# 1980   538375067                              Xanadu
# 1981   389925971                Zorro: The Gay Blade
# 1982   792910554                             Zapped!
# 1983   475106177                               Zelig
# 1984   333107271                       Winter Flight
# 1985   381906762               Young Sherlock Holmes
# 1986   357288178                          Youngblood
# 1987   320145693                        Withnail & I
# 1988   354825435                          Young Guns
# 1989   474171806                       Worth Winning
# 1990   505703557                       Young Guns II
# 1991   520881154                     Year of the Gun
# 1992   504050219                           Zebrahead
# ...

# %%
#the gross for each company in every year
df.groupby(["year" ])["company","gross"].max()
# Out:
# <ipython-input-47-4d3399e4e9c7>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby(["year" ])["company","gross"].max()
#                                 company       gross
# year
# 1980                       Warner Bros.   538375067
# 1981                   Zoetrope Studios   389925971
# 1982                   Zoetrope Studios   792910554
# 1983                            unknown   475106177
# 1984                            unknown   333107271
# 1985                   Zoetrope Studios   381906762
# 1986                            unknown   357288178
# 1987               Zenith Entertainment   320145693
# 1988           Zanuck/Brown Productions   354825435
# 1989                            unknown   474171806
# 1990                            unknown   505703557
# 1991                       Warner Bros.   520881154
# 1992                 Zeta Entertainment   504050219
# ...

# %%
#the maximum gross for each company
df.groupby(["gross"])["company"].max()
# Out:
# gross
# 0                                    unknown
# 309                                 Daybreak
# 596           DENTSU Music And Entertainment
# 682                            Roxwell Films
# 790                Visual Arts Entertainment
#                            ...
# 2048359754                    Marvel Studios
# 2069521700                         Lucasfilm
# 2201647264             Twentieth Century Fox
# 2797501328                    Marvel Studios
# 2847246203             Twentieth Century Fox
# Name: company, Length: 7473, dtype: object

# %%
df.groupby(["company","name" ])["budget"].sum()
# Out:
# company                              name
# "DIA" Productions GmbH & Co. KG      A Man Apart            36000000
# "Weathering With You" Film Partners  Weathering with You    11100000
# .406 Production                      Schizopolis              250000
# 1+2 Seisaku Iinkai                   Yi Yi                         0
# 10 West Studios                      What If...                    0
#                                                               ...
# unknown                              Streets                       0
#                                      The Bear                 221000
#                                      The Robinsons             10000
#                                      The Wolfman                   0
#                                      White Star               100000
# Name: budget, Length: 7653, dtype: int64
